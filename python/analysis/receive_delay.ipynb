# %% [markdown]
# ## データのタイムスタンプと受信時刻による遅延

# %%
import pandas

# %%
execution_df = pandas.read_json("receive_execution_delays.json")
ticker_df = pandas.read_json("receive_ticker_delays.json")

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly

# %matplotlib notebook

# %%
sns.distplot(execution_df["avg_delay_msec"].values)
sns.distplot(ticker_df["avg_delay_msec"].values)
# Out:
# <img src="data:image/png;base64,..." width="672">
# /home/alatani/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#
# /home/alatani/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.

# %%
import scipy.stats
print("execution",scipy.stats.describe(execution_df["avg_delay_msec"].values))
print("ticker   ",scipy.stats.describe(ticker_df["avg_delay_msec"].values))
# Out:
# execution DescribeResult(nobs=5213, minmax=(161.52941176470586, 21147.408408408417), mean=388.99270427361165, variance=179399.92809589847, skewness=28.87304701646816, kurtosis=1230.060500435865)
# ticker    DescribeResult(nobs=5557, minmax=(101.0, 6310.142857142857), mean=293.3096766323001, variance=42126.666325333426, skewness=16.534239001636525, kurtosis=379.6708223117985)
